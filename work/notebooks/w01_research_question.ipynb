# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Fill this honestly. A well-framed question beats a brilliant model every time.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# # I want to analyze what specific on-page and structural factors most strongly correlate with higher search visibility. Understanding these patterns will allow us to prioritize SEO and content investments based on data, rather than guessing what search engines reward

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Decision: Which specific web pages should we update, and which specific features (e.g., metadata, word count, readability) should we prioritize?
#
# Action: The content and engineering teams will allocate resources to update the flagged pages with the recommended features.
#
# Cost of a wrong call: Wasting expensive engineering and content hours on updates that do not move the needle, resulting in zero ROI and lost traffic opportunities.
#
# Why ML: The dataset contains thousands of pages and dozens of overlapping variables. Traditional data retrieval cannot easily weigh the complex, combined impact of these features on rankings, whereas machine learning can identify these multi-dimensional patterns.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

# Load the dataset directly from your public GitHub repository's raw URL
csv_url = "https://raw.githubusercontent.com/chahmadraza89/flyrank-ml-internship/main/data/raw/content_refresh_anonymized.csv"

# Read the CSV
df = pd.read_csv(csv_url)

# Show shape and basic stats
print(f"Dataset shape: {df.shape}")

# Calculate 2-3 real numbers
total_records = len(df)
baseline_win_rate = 24.0 # Baseline rule success rate from Notebook 01

print(f"Total pages/records to analyze: {total_records}")
print(f"Current baseline rule success rate to beat: {baseline_win_rate}%")
# Out:
# Dataset shape: (30000, 44)
# Total pages/records to analyze: 30000
# Current baseline rule success rate to beat: 24.0%

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'prediction' without limits).*

# %% [markdown]
# What I CAN claim: I can provide observed, directional insights and decision-support metrics showing how certain on-page features correlate with better rankings in this specific dataset.
#
# What I CANNOT claim: I cannot claim causal proof (e.g., "doing X definitively causes Y"), nor can I claim absolute certainty or that I am perfectly "predicting Google's exact algorithm."

# %%
# Describe what you CAN claim (observed, directional, decision-support)
# Describe what you CANNOT claim (causal, certainty, etc.)

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom without error
# - [ ] My frame answers: decision, actor, cost, why-ML (all four)
# - [ ] I loaded the CSV and showed real numbers (not 'seems interesting')
# - [ ] I named what I can and can't claim — no overreach
